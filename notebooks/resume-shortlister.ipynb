# %% [markdown]
# # Initialization

# %%
# Open Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
import json
import subprocess
import spacy
import shutil

from spacy.tokens import DocBin, Doc, Span
from spacy.util import filter_spans
from google.colab import drive
from pathlib import Path

# Specify the path to your dataset and the target folder
dataset_path = '/content/drive/MyDrive/resume-shortlister/dataset/'
augmented_data_path = '/content/drive/MyDrive/resume-shortlister/augmented_data/'
spacy_dataset_path = '/content/drive/MyDrive/resume-shortlister/spacy_dataset/'

training_data_path = '/content/drive/MyDrive/resume-shortlister/training_data/'
testing_data_path = '/content/drive/MyDrive/resume-shortlister/testing_data/'

nlp = spacy.blank("en")

# %% [markdown]
# # Convert annotated data into JSON data of spacy type

# %%
def convert_json_to_spacy(json_path, output_path):
    # Load the JSON file
    with open(json_path, 'r', encoding='utf-8') as json_file:
        data = json.load(json_file)
        doc_bin = DocBin()  # Create a DocBin to store the documents

        # Iterate through the annotations
        for text, ann in data['annotations']:
            doc = nlp.make_doc(text)  # Create a Doc object from the text
            ents = []
            for start, end, label in ann['entities']:  # Extract entities
                span = doc.char_span(start, end, label=label)  # Create a span
                if span is not None:
                    ents.append(span)
            doc.ents = ents  # Assign the entities to the doc
            doc_bin.add(doc)  # Add the doc to the DocBin

    # Save the DocBin to disk
    doc_bin.to_disk(output_path)

Path(spacy_dataset_path).mkdir(parents=True, exist_ok=True)  # Ensure the output directory exists
# Convert all JSON files in the directory
for json_file in Path(dataset_path).glob('*.json'):
    output_file = Path(spacy_dataset_path) / f'{json_file.stem}.spacy'
    convert_json_to_spacy(json_file, output_file)
    print(f"Converted {json_file.name} to .spacy format at {output_file}")
# Out:
# Converted Maleesha_Thalagala.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Maleesha_Thalagala.spacy
# Converted Sachith_Priyashantha.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sachith_Priyashantha.spacy
# Converted Milinda_Senaka.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Milinda_Senaka.spacy
# Converted Dinooli_Uduwarage_SE.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dinooli_Uduwarage_SE.spacy
# Converted Ayesha_Ekanayake.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ayesha_Ekanayake.spacy
# Converted Kavindi_Gunasekara.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kavindi_Gunasekara.spacy
# Converted Widuranga_Dilruksha.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Widuranga_Dilruksha.spacy
# Converted Hasanga_Lakdinu.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hasanga_Lakdinu.spacy
# Converted Raviru_I_Jayathilake.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Raviru_I_Jayathilake.spacy
# Converted Thisuru_Deesan.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thisuru_Deesan.spacy
# Converted Lakruwan_Hettiaracchi.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lakruwan_Hettiaracchi.spacy
# Converted Supuni_Saradha.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Supuni_Saradha.spacy
# Converted Tharmeala_Anton.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Tharmeala_Anton.spacy
# Converted Suhadini_Kaluarachchi.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Suhadini_Kaluarachchi.spacy
# Converted Ashinka_Abeyweera.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ashinka_Abeyweera.spacy
# Converted Lakshika_Swarnamali.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lakshika_Swarnamali.spacy
# Converted Nirmal_Aththanayaka.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nirmal_Aththanayaka.spacy
# Converted Pavini_Weerasinghe.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pavini_Weerasinghe.spacy
# Converted Anoja_Gnaneswaran.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Anoja_Gnaneswaran.spacy
# Converted Rashmi_Erandika.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Rashmi_Erandika.spacy
# Converted Thulya_Palihapitiya.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thulya_Palihapitiya.spacy
# Converted Hasindu_Muhandiram.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hasindu_Muhandiram.spacy
# Converted Chameera_Dulanga.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chameera_Dulanga.spacy
# Converted Lahiru_De_Silva.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lahiru_De_Silva.spacy
# Converted Janith_Gamage.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Janith_Gamage.spacy
# Converted Ishani_Dasanayake.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ishani_Dasanayake.spacy
# Converted Piumi_Hansika.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piumi_Hansika.spacy
# Converted Dumika_Jayarathna.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dumika_Jayarathna.spacy
# Converted Pradeep_Ranasinghe.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pradeep_Ranasinghe.spacy
# Converted Imalka_Prasadini.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Imalka_Prasadini.spacy
# Converted Tharinduni_Kaushalya.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Tharinduni_Kaushalya.spacy
# Converted Vidya_Wimalasooriya.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Vidya_Wimalasooriya.spacy
# Converted Rasinkani_De_Silva.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Rasinkani_De_Silva.spacy
# Converted Sureka_Ranjani.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sureka_Ranjani.spacy
# Converted Tharmi_Vijayakumaran.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Tharmi_Vijayakumaran.spacy
# Converted Chanduka_Samarasinghe.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chanduka_Samarasinghe.spacy
# Converted Buddhika_Chathuranga.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Buddhika_Chathuranga.spacy
# Converted Shameela_Ashker.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Shameela_Ashker.spacy
# Converted Dilini_Mendis.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dilini_Mendis.spacy
# Converted Sachithra_Rathnayake.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sachithra_Rathnayake.spacy
# Converted Charuka_Herath.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Charuka_Herath.spacy
# Converted Heshan_Kavinda.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Heshan_Kavinda.spacy
# Converted Kirisanthi_Selvanajagam.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kirisanthi_Selvanajagam.spacy
# Converted Piyumitha_Nirman.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piyumitha_Nirman.spacy
# Converted Bushra_Uwais.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Bushra_Uwais.spacy
# Converted Asiri_Geethika.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Asiri_Geethika.spacy
# Converted Nipupulee_Hansamali.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nipupulee_Hansamali.spacy
# Converted RAGAVENTHAN_SIVAPATHASUNDARAM.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/RAGAVENTHAN_SIVAPATHASUNDARAM.spacy
# Converted Gihan_Kadawathage.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gihan_Kadawathage.spacy
# Converted Mathula_Krishnaraja.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mathula_Krishnaraja.spacy
# Converted Wimarshika_Thamali.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Wimarshika_Thamali.spacy
# Converted Vimukthi_Mayadunne.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Vimukthi_Mayadunne.spacy
# Converted Ovindu_Wijethunge.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ovindu_Wijethunge.spacy
# Converted Ishara_De_Silva.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ishara_De_Silva.spacy
# Converted Umith_SE - G.A.U.I. WIMALARATHNA.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Umith_SE - G.A.U.I. WIMALARATHNA.spacy
# Converted Vindya Perera.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Vindya Perera.spacy
# Converted Lakshika_Abeysinghe.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lakshika_Abeysinghe.spacy
# Converted Samadhi Mathara arachchi.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Samadhi Mathara arachchi.spacy
# Converted Chiranga_Wickramasinghe.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chiranga_Wickramasinghe.spacy
# Converted Loganayagam_Araharan.json to .spacy format at /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Loganayagam_Araharan.spacy

# %% [markdown]
# # Data Augmentation

# %%
# Expanded Entity substitution map and lists
entity_map = {
    "TECHNICAL SKILLS": [
        "Python", "JavaScript", "C++", "Angular", "Java", "Spring Boot", "Rust", "Node.js", "Docker",
        "AWS", "TensorFlow", "React.js", "Kubernetes", "SQL", "NoSQL", "MongoDB", "Azure", "Machine Learning",
        "Deep Learning", "PyTorch", "Pandas", "Data Visualization", "Cybersecurity", "ERP Solutions", "Salesforce"
    ],
    "NON TECHNICAL SKILLS": [
        "leadership", "communication", "teamwork", "problem solving", "time management",
        "project management", "strategic planning", "customer service", "agile methodologies",
        "public speaking", "critical thinking", "negotiation", "adaptability", "emotional intelligence"
    ],
    "EXPERIENCES": [
        "internship at Google", "internship at Amazon", "software development at a startup",
        "research assistantship in machine learning", "part-time developer at a local tech firm",
        "software engineering at Virtusa", "IT consultancy at WSO2", "data analysis at Pearson Lanka",
        "cloud engineering at Sysco LABS", "project management at MillenniumIT ESP"
    ],
    "DEGREE": [
        "B.Sc. Computer Science", "M.Sc. Data Science", "Ph.D. in Artificial Intelligence",
        "B.Eng. Software Engineering", "B.Sc. in Information Technology",
        "B.Sc. in Network Technology", "M.Sc. in Cybersecurity", "B.Sc. in Interactive Media",
        "M.Sc. in Big Data Analytics", "Ph.D. in Computational Biology"
    ],
    "AL STREAM": [
        "Biology", "Information Technology", "Physical Science", "Commerce", "Arts",
        "Mathematics", "Engineering Technology", "Bio-system Technology", "Health Science"
    ],
    "PROJECTS": [
        "machine learning model for predicting stock prices", "web development for a local business",
        "mobile app for campus navigation", "blockchain-based voting system", "IoT home automation system",
        "AI-driven chatbot for customer service", "e-commerce platform optimization using data analytics",
        "virtual reality application for real estate", "augmented reality educational tools",
        "smart city traffic management system"
    ],
    "OTHER EXPERIENCES": [
        "volunteering at an NGO for teaching coding to kids", "teaching assistant in a computer science course",
        "freelance graphic designer for digital marketing", "tech blog writer", "open source contributor",
        "member of the IEEE Student Branch", "organizer of local hackathons", "mentor in coding bootcamps",
        "participant in National IT competitions", "volunteer in disaster recovery initiatives"
    ],
}

first_names = [
    "Thilini", "Avishka", "Asini", "Dulani", "Harini", "Yasas", "Mihindu", "Ashani", "Navindu", "Anuda",
    "Lahiru", "Chamari", "Isuru", "Madushani", "Nipuna", "Sanjaya", "Maneesha", "Roshan", "Kavindya", "Sachith",
    "Nirmal", "Pradeep", "Sahan", "Sanduni", "Pavithra", "Chathura", "Danushka", "Gayathri", "Hiruni", "Janith",
    "Kusal", "Malith", "Nadeesha", "Oshada", "Prashani", "Ruvini", "Sajith", "Tharindu", "Udara", "Vihanga",
    "Yohan", "Zahra", "Bimsara", "Chamath", "Dinuka", "Eranga", "Fathima", "Gihan", "Hansika", "Indeewari",
    "Jeewan", "Kasun", "Lasith", "Mahesh", "Nimasha", "Omal", "Piumi", "Rashmi", "Suresh", "Thushara"
]
last_names = [
    "Samarasinghe", "Fernando", "De Silva", "Ranasinghe", "Perera", "Amarasinghe", "Gunarathna", "Senaka", "Senarath", "Liyanage",
    "Jayawardena", "Rajapaksa", "Bandara", "Wickramasinghe", "Herath", "Silva", "Kumara", "Dissanayake", "Rathnayake", "Jayasuriya",
    "Karunaratne", "Weerasinghe", "Rodrigo", "Abeysekara", "Balasooriya", "Chandrasekara", "Dharmaratne", "Ekanayake", "Fonseka", "Gamage",
    "Hewavitharana", "Ilangaratne", "Jayakody", "Kotalawala", "Lakshman", "Mendis", "Nanayakkara", "Pathirana", "Ranatunga", "Seneviratne",
    "Thalagala", "Udawatte", "Vithanage", "Wijesinghe", "Yapa", "Zoysa", "Athukorala", "Bandaranaike", "Coomaraswamy", "Deshapriya"
]

# %%
def generate_text(new_data):
    """
    Generates descriptive text from structured data incorporating all attributes.
    Adds a period at the end to help with token boundary detection.
    """
    other_experiences = ', '.join(new_data['OTHER EXPERIENCES'])
    tech_skills = ', '.join(new_data['TECHNICAL SKILLS'])
    non_tech_skills = ', '.join(new_data['NON TECHNICAL SKILLS'])

    text = (
        f"{new_data['CANDIDATE NAME']} recently graduated with a {new_data['DEGREE']} "
        f"from the {new_data['AL STREAM']} stream, achieving a GPA of {new_data['GPA']}. "
        f"Worked on the project titled '{new_data['PROJECTS']}', gained experience as "
        f"{new_data['EXPERIENCES']}, and was involved in {other_experiences}. Known for expertise in {tech_skills} "
        f"and also possesses skills in {non_tech_skills}. "
        f"More on their professional profile can be seen at {new_data['LINKEDIN URL']} "
        f"or {new_data['GITHUB URL']}."
    ).strip() + '.'  # Ensuring the text ends with a period

    return text

def create_spacy_training_data(new_data, nlp):
    text = generate_text(new_data)
    doc = nlp(text)
    entities = []

    for label, value in new_data.items():
        if isinstance(value, list):
            value = ', '.join(value)  # Ensure this matches generate_text exactly
        value = str(value)  # Convert everything to string to avoid type issues

        start = text.find(value)
        if start == -1:
            print(f"Value for {label} not found in text: {value}")
            continue

        end = start + len(value)
        span = doc.char_span(start, end, alignment_mode='contract')
        if span is not None:
            entities.append((span.start_char, span.end_char, label))
        else:
            print(f"Skipping entity due to misalignment: {label} at {start}-{end}")

    return (text, {'entities': entities})

def augment_and_save_data(nlp):
    first_name = random.choice(first_names)
    last_name = random.choice(last_names)
    candidate_name = f"{first_name} {last_name}"
    gpa = round(random.uniform(2.0, 4.0), 2)

    new_data = {
        "CANDIDATE NAME": candidate_name,
        "TECHNICAL SKILLS": random.sample(entity_map["TECHNICAL SKILLS"], random.randint(3, 5)),
        "NON TECHNICAL SKILLS": random.sample(entity_map["NON TECHNICAL SKILLS"], random.randint(3, 5)),
        "EXPERIENCES": random.choice(entity_map["EXPERIENCES"]),
        "DEGREE": random.choice(entity_map["DEGREE"]),
        "GPA": str(gpa),
        "AL STREAM": random.choice(entity_map["AL STREAM"]),
        "PROJECTS": random.choice(entity_map["PROJECTS"]),
        "OTHER EXPERIENCES": random.sample(entity_map["OTHER EXPERIENCES"], random.randint(1, 3)),
        "LINKEDIN URL": f"https://www.linkedin.com/in/{candidate_name.replace(' ', '.').lower()}/",
        "GITHUB URL": f"https://github.com/{candidate_name.replace(' ', '.').lower()}/"
    }

    training_example = create_spacy_training_data(new_data, nlp)
    new_filename = f"{candidate_name.replace(' ', '_')}.json"
    new_file_path = Path(augmented_data_path) / new_filename
    with open(new_file_path, 'w') as file:
        json.dump(training_example, file)

# Create the directory if it does not exist
Path(augmented_data_path).mkdir(parents=True, exist_ok=True)
# Generate and save multiple augmented data files
for _ in range(500):  # Adjust as needed
    augment_and_save_data(nlp)

print("Data augmentation complete and files saved.")
# Out:
# Data augmentation complete and files saved.

# %%
def convert_json_to_spacy(json_path, output_path):
    with open(json_path, 'r', encoding='utf-8') as file:
        data = json.load(file)  # Load the JSON data
        doc_bin = DocBin()  # Create a DocBin to store the documents

        # Directly access text and annotations
        text = data[0]
        annotations = data[1]

        doc = nlp.make_doc(text)
        ents = []
        covered = set()

        for start, end, label in sorted(annotations['entities'], key=lambda x: x[0]):
            if any(pos in covered for pos in range(start, end)):
                print(f"Skipping overlapping entity {label} at {start}:{end}.")
                continue
            span = doc.char_span(start, end, label=label, alignment_mode='contract')
            if span:
                ents.append(span)
                covered.update(range(start, end))
            else:
                print(f"Skipping entity {label} at {start}:{end} due to misalignment.")

        doc.ents = ents
        doc_bin.add(doc)

    doc_bin.to_disk(output_path)
    print(f"Saved converted file to {output_path}")

def convert_directory(json_dir, spacy_dir):
    json_dir_path = Path(json_dir)
    spacy_dir_path = Path(spacy_dir)
    spacy_dir_path.mkdir(parents=True, exist_ok=True)

    for json_file in json_dir_path.glob('*.json'):
        output_file = spacy_dir_path / f'{json_file.stem}.spacy'
        convert_json_to_spacy(json_file, output_file)

convert_directory(augmented_data_path, spacy_dataset_path)
# Out:
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Eranga_Hewavitharana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lahiru_Dharmaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Oshada_Abeysekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kusal_Senarath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kavindya_Senarath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Isuru_Dharmaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sahan_Wickramasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Harini_Vithanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Asini_Kumara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Eranga_Dharmaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Rashmi_Jayakody.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kasun_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mihindu_Senaka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chamath_Bandara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yasas_Zoysa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chamath_Thalagala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Harini_Herath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ashani_Gunarathna.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ashani_Jayawardena.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hiruni_Jayakody.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nipuna_Ranasinghe.spacy
# Skipping overlapping entity AL STREAM at 69:76.
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nimasha_Balasooriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gayathri_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Bimsara_Mendis.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sachith_Ranasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Isuru_Rajapaksa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Jeewan_Athukorala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Bimsara_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Isuru_Coomaraswamy.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanduni_Seneviratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Rashmi_Lakshman.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nipuna_Pathirana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Anuda_Coomaraswamy.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gihan_Rajapaksa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lasith_Athukorala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hansika_Ilangaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Navindu_Chandrasekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lahiru_Thalagala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yasas_Udawatte.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Fathima_Weerasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Zahra_Senarath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dinuka_Kotalawala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Asini_Vithanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Madushani_Ekanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Bimsara_Coomaraswamy.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Indeewari_Ilangaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Janith_Gamage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gihan_Chandrasekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nirmal_Deshapriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Roshan_Amarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piumi_Amarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Omal_Karunaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Harini_Zoysa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kasun_Mendis.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hansika_Jayawardena.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Avishka_Herath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanduni_Wijesinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gayathri_Yapa.spacy
# Skipping overlapping entity AL STREAM at 63:70.
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nimasha_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pradeep_Deshapriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sachith_Athukorala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Suresh_Pathirana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dinuka_Deshapriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ashani_Rodrigo.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gayathri_Gamage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Vihanga_Ilangaratne.spacy
# Skipping overlapping entity AL STREAM at 50:72.
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thilini_Senaka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nipuna_Dharmaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piumi_Fonseka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kusal_Udawatte.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Rashmi_Jayawardena.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Harini_Hewavitharana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sajith_Senarath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kusal_Liyanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Tharindu_Deshapriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piumi_Rodrigo.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Navindu_Gamage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanduni_Pathirana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ashani_Jayakody.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pradeep_Fonseka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Madushani_Mendis.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Madushani_Chandrasekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanduni_Amarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Jeewan_Bandara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ruvini_Wickramasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chathura_Amarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thilini_Bandara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piumi_Coomaraswamy.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanjaya_Nanayakkara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Roshan_Ekanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thushara_Liyanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Prashani_Senaka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Prashani_Rathnayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Avishka_Fernando.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Asini_Rathnayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Zahra_Coomaraswamy.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chamath_Senaka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Eranga_De_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ruvini_Herath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hansika_Vithanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Jeewan_Karunaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lahiru_Zoysa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gihan_Senaka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sachith_Mendis.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Roshan_Ilangaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Rashmi_Senarath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nadeesha_Hewavitharana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Zahra_Mendis.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nirmal_Chandrasekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sajith_Coomaraswamy.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lahiru_Jayawardena.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Isuru_Jayakody.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lahiru_Pathirana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lasith_Liyanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yohan_Wickramasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Danushka_Amarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Indeewari_Abeysekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Udara_Rodrigo.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gayathri_Samarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chamari_Ranasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Udara_Yapa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nadeesha_Liyanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanjaya_Yapa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kavindya_Abeysekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sachith_Coomaraswamy.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sahan_Senaka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Oshada_Kotalawala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Vihanga_Dharmaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nipuna_Jayasuriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Roshan_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Janith_Deshapriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nirmal_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mahesh_Dharmaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mihindu_Nanayakkara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chamari_Samarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Vihanga_Bandara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Maneesha_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Eranga_Herath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanjaya_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Navindu_Pathirana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Anuda_Abeysekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Eranga_Liyanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Anuda_Perera.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kusal_Jayakody.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thushara_Wickramasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Asini_Perera.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nimasha_Athukorala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Rashmi_Seneviratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nipuna_Coomaraswamy.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Avishka_Balasooriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yasas_Fernando.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sahan_Perera.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lasith_Zoysa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Asini_Wickramasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Fathima_De_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thilini_Jayawardena.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hiruni_Zoysa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gayathri_Chandrasekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Navindu_Yapa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sajith_De_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yohan_Vithanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mahesh_Fonseka.spacy
# Skipping overlapping entity AL STREAM at 68:75.
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Danushka_Rajapaksa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Madushani_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gayathri_Balasooriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Tharindu_Vithanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chamari_Dissanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sajith_Fonseka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Omal_Gamage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mihindu_Wickramasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pradeep_Samarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Bimsara_Kumara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Omal_Abeysekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chathura_Liyanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dinuka_Senarath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sachith_Perera.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kavindya_Chandrasekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kusal_Chandrasekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hiruni_Fonseka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yasas_Abeysekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nipuna_Weerasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dinuka_Wickramasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nirmal_Ilangaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yohan_Fernando.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mihindu_Zoysa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Indeewari_Pathirana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanduni_Kumara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yasas_De_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thilini_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hiruni_Perera.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Rashmi_Hewavitharana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sachith_Amarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kasun_Pathirana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Prashani_Chandrasekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chathura_Ranasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pavithra_Jayasuriya.spacy
# Skipping overlapping entity AL STREAM at 47:69.
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piumi_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nirmal_Seneviratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nirmal_Mendis.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piumi_Pathirana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Oshada_Bandara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chathura_Kumara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thushara_Senarath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yasas_Perera.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Harini_Abeysekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Jeewan_Rathnayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sajith_Yapa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nipuna_Vithanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hansika_Samarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Jeewan_Ranasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Maneesha_Gunarathna.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pavithra_Amarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nimasha_Dharmaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Maneesha_Rathnayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Navindu_Hewavitharana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Anuda_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kusal_Wijesinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Harini_Wickramasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Eranga_Senaka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mahesh_Chandrasekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Fathima_Nanayakkara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Suresh_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Suresh_Karunaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dulani_Kotalawala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chathura_Balasooriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Isuru_Fonseka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gihan_Dissanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Isuru_Rathnayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Suresh_Yapa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Indeewari_Nanayakkara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hansika_Chandrasekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hiruni_Jayawardena.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thilini_Amarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Tharindu_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pavithra_Fernando.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Oshada_Herath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hiruni_Gunarathna.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mahesh_Nanayakkara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piumi_Gamage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Prashani_Coomaraswamy.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mihindu_Fonseka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hansika_Nanayakkara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pradeep_Athukorala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Vihanga_Thalagala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Malith_Samarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanduni_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hansika_Ekanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nirmal_Hewavitharana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Prashani_Jayawardena.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Madushani_Jayakody.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kusal_Seneviratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mihindu_Samarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hansika_Wijesinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kusal_Samarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Suresh_Jayasuriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Danushka_Thalagala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thushara_Ranasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kasun_Rodrigo.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yohan_Seneviratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Fathima_Amarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chamath_Senarath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yohan_Senaka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Jeewan_Senaka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ashani_Fonseka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Fathima_Ekanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Bimsara_Athukorala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nipuna_Gamage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Asini_Senarath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chamath_Rathnayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dulani_Dissanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Asini_Rajapaksa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nimasha_Gunarathna.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Janith_Fernando.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Harini_Karunaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Navindu_Wickramasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Rashmi_Bandara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thushara_Ekanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pavithra_Seneviratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanjaya_Rajapaksa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nipuna_Liyanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sahan_Senarath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Tharindu_Abeysekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Asini_Abeysekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kasun_Senarath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Harini_Seneviratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Eranga_Ekanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dulani_Vithanage.spacy
# Skipping overlapping entity AL STREAM at 65:72.
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Rashmi_Udawatte.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sajith_Ranasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Omal_Lakshman.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Malith_Jayawardena.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thilini_Yapa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sajith_Samarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Vihanga_Jayawardena.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Zahra_Udawatte.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Oshada_Ekanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Prashani_Udawatte.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Anuda_Gamage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hiruni_Mendis.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mahesh_Herath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Fathima_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dulani_Rajapaksa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pradeep_Yapa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chamath_Gamage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Udara_Fonseka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mihindu_Deshapriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Asini_Athukorala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Bimsara_Chandrasekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hansika_De_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nadeesha_Nanayakkara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yohan_Hewavitharana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Omal_Samarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lasith_Weerasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Fathima_Perera.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Indeewari_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nadeesha_Abeysekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanduni_Zoysa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lasith_Dharmaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chathura_Mendis.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Janith_Rodrigo.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Omal_Dissanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pavithra_Bandara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kusal_Weerasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Maneesha_Rodrigo.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nirmal_Liyanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Malith_Udawatte.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nirmal_Rajapaksa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Madushani_Fonseka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yohan_Lakshman.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Isuru_Ranatunga.spacy
# Skipping overlapping entity AL STREAM at 56:78.
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Prashani_Nanayakkara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chathura_Jayakody.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yasas_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chamari_Gamage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Asini_Senaka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nadeesha_Fonseka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Bimsara_Dissanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Madushani_Karunaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Indeewari_Dissanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Danushka_Senarath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Suresh_Rathnayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Avishka_Liyanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pavithra_Vithanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pavithra_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Zahra_Wijesinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kavindya_Vithanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Oshada_Perera.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Maneesha_Dissanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sachith_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Harini_Lakshman.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanjaya_Zoysa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Fathima_Jayakody.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Vihanga_Wickramasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mahesh_Samarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yohan_Jayasuriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Udara_Ilangaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Roshan_Jayasuriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chathura_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Suresh_Bandara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sahan_Deshapriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nipuna_Nanayakkara.spacy
# Skipping overlapping entity AL STREAM at 65:72.
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Isuru_Ekanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hiruni_Kumara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ruvini_Vithanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kusal_Kumara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sachith_Kumara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nimasha_Wickramasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thushara_De_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Udara_Athukorala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kusal_Fonseka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hansika_Ranasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nipuna_Udawatte.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Suresh_Chandrasekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piumi_Fernando.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chathura_Samarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Maneesha_Zoysa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanjaya_Bandara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yasas_Jayawardena.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Vihanga_Gunarathna.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yohan_Gamage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanduni_Chandrasekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yasas_Rajapaksa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Vihanga_Samarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kavindya_Mendis.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dinuka_Nanayakkara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Bimsara_Ranatunga.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Madushani_Thalagala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kasun_Gunarathna.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thilini_Nanayakkara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pavithra_Ekanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Maneesha_Balasooriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thilini_Pathirana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Roshan_Hewavitharana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Malith_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sahan_Jayawardena.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kavindya_Fonseka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Navindu_Balasooriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Tharindu_Senaka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gihan_Abeysekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sajith_Bandara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piumi_Gunarathna.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Indeewari_Jayasuriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Anuda_Mendis.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanjaya_Dissanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ashani_Karunaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Suresh_Ekanayake.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Zahra_Balasooriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Malith_Amarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sahan_Jayakody.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kusal_Deshapriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Rashmi_Ilangaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thushara_Fernando.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Indeewari_Ranatunga.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mahesh_Ilangaratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gihan_Balasooriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Asini_Yapa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Udara_Ranatunga.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Asini_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Tharindu_Bandara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Janith_Liyanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Omal_Kumara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piumi_Perera.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Pradeep_Wickramasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanduni_Wickramasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hansika_Abeysekara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Eranga_Gunarathna.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piumi_Zoysa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Anuda_Ranatunga.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Bimsara_Kotalawala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Janith_Vithanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chamath_Ranasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yasas_Seneviratne.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Fathima_Yapa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Kavindya_Yapa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Mihindu_Vithanage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nirmal_Fernando.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nimasha_Perera.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chamari_Rodrigo.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Indeewari_Coomaraswamy.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Indeewari_Gamage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Anuda_Bandara.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dulani_Deshapriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yohan_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Nipuna_Rajapaksa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Thushara_Yapa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Zahra_Hewavitharana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Malith_Coomaraswamy.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Ashani_Zoysa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Harini_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chathura_Pathirana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dinuka_Samarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yohan_Kotalawala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Maneesha_Wijesinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Hansika_Senaka.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lahiru_Bandaranaike.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lahiru_Udawatte.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Gihan_Pathirana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sanjaya_Athukorala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lasith_De_Silva.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Madushani_Lakshman.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Yohan_Amarasinghe.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Jeewan_Jayasuriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Zahra_Yapa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Suresh_Senarath.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Vihanga_Gamage.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Lahiru_Deshapriya.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Dulani_Hewavitharana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Rashmi_Yapa.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Piumi_Hewavitharana.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Chamath_Kotalawala.spacy
# Saved converted file to /content/drive/MyDrive/RashmikaFYP/spacy_dataset/Sachith_Wijesinghe.spacy

# %% [markdown]
# # Train Model

# %%
# !python -m spacy init config --lang en --pipeline ner --optimize efficiency /content/drive/MyDrive/resume-shortlister/config/base_config.cfg --gpu-id 0
# Out:
# ✘ The provided output file already exists. To force overwriting the
# config file, set the --force or -F flag.

# %% [markdown]
# [paths]
# train = "/content/drive/MyDrive/RashmikaFYP/spacy_dataset/"
# dev = "/content/drive/MyDrive/RashmikaFYP/spacy_dataset/"
# vectors = null
# init_tok2vec = null
#
# [system]
# gpu_allocator = null
# seed = 0
#
# [nlp]
# lang = "en"
# pipeline = ["tok2vec","ner"]
# batch_size = 1000
# disabled = []
# before_creation = null
# after_creation = null
# after_pipeline_creation = null
# tokenizer = {"@tokenizers":"spacy.Tokenizer.v1"}
# vectors = {"@vectors":"spacy.Vectors.v1"}
#
# [components]
#
# [components.ner]
# factory = "ner"
# incorrect_spans_key = null
# moves = null
# scorer = {"@scorers":"spacy.ner_scorer.v1"}
# update_with_oracle_cut_size = 100
#
# [components.ner.model]
# @architectures = "spacy.TransitionBasedParser.v2"
# state_type = "ner"
# extra_state_tokens = false
# hidden_width = 64
# maxout_pieces = 2
# use_upper = true
# nO = null
#
# [components.ner.model.tok2vec]
# @architectures = "spacy.Tok2VecListener.v1"
# width = ${components.tok2vec.model.encode.width}
# upstream = "*"
#
# [components.tok2vec]
# factory = "tok2vec"
#
# [components.tok2vec.model]
# @architectures = "spacy.Tok2Vec.v2"
#
# [components.tok2vec.model.embed]
# @architectures = "spacy.MultiHashEmbed.v2"
# width = ${components.tok2vec.model.encode.width}
# attrs = ["NORM","PREFIX","SUFFIX","SHAPE"]
# rows = [5000,1000,2500,2500]
# include_static_vectors = false
#
# [components.tok2vec.model.encode]
# @architectures = "spacy.MaxoutWindowEncoder.v2"
# width = 96
# depth = 4
# window_size = 1
# maxout_pieces = 3
#
# [corpora]
#
# [corpora.dev]
# @readers = "spacy.Corpus.v1"
# path = ${paths.dev}
# max_length = 0
# gold_preproc = false
# limit = 0
# augmenter = null
#
# [corpora.train]
# @readers = "spacy.Corpus.v1"
# path = ${paths.train}
# max_length = 0
# gold_preproc = false
# limit = 0
# augmenter = null
#
# [training]
# dev_corpus = "corpora.dev"
# train_corpus = "corpora.train"
# seed = ${system.seed}
# gpu_allocator = ${system.gpu_allocator}
# dropout = 0.2
# accumulate_gradient = 1
# patience = 500
# max_epochs = 100
# max_steps = 20000
# eval_frequency = 100
# frozen_components = []
# annotating_components = []
# before_to_disk = null
# before_update = null
#
# [training.batcher]
# @batchers = "spacy.batch_by_words.v1"
# discard_oversize = false
# tolerance = 0.2
# get_length = null
#
# [training.batcher.size]
# @schedules = "compounding.v1"
# start = 10
# stop = 50
# compound = 1.001
#
# [training.logger]
# @loggers = "spacy.ConsoleLogger.v1"
# progress_bar = false
#
# [training.optimizer]
# @optimizers = "Adam.v1"
# beta1 = 0.9
# beta2 = 0.999
# L2_is_weight_decay = true
# L2 = 0.1
# grad_clip = 1.0
# use_averages = false
# eps = 0.00000001
# learn_rate = 0.001
#
# [training.score_weights]
# ents_f = 1.0
# ents_p = 0.0
# ents_r = 0.0
# ents_per_type = null
#
# [pretraining]
#
# [initialize]
# vectors = ${paths.vectors}
# init_tok2vec = ${paths.init_tok2vec}
# vocab_data = null
# lookups = null
# before_init = null
# after_init = null
#
# [initialize.components]
#
# [initialize.tokenizer]

# %%
# Finalize config
# !python -m spacy init fill-config /content/drive/MyDrive/resume-shortlister/config/base_config.cfg /content/drive/MyDrive/resume-shortlister/config/final_config.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# /content/drive/MyDrive/RashmikaFYP/config/final_config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train final_config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# Define the path to your specific .spacy file
# spacy_file_path = '/content/drive/MyDrive/resume-shortlister/testing_data/Maleesha_Thalagala.spacy'  # Change 'your_file.spacy' to the actual file name
spacy_file_path = '/content/drive/MyDrive/resume-shortlister/training_data/Maleesha_Thalagala.spacy'  # Change 'your_file.spacy' to the actual file name

# Load a .spacy file
doc_bin = DocBin().from_disk(spacy_file_path)
docs = list(doc_bin.get_docs(nlp.vocab))

for doc in docs:
    for ent in doc.ents:
        print(ent.text, ent.label_)
# Out:
# MALEESHA THALAGALA CANDIDATE NAME
# Level-4 Project: Identifying the Prevalence of Depression Using Twitter
# (Ongoing Research Project) PROJECTS
# Internship Project at ISA: AeroCONNECT PROJECTS
# B.SC(Hon’s)Information Technology and Management DEGREE
# Java TECHNICAL SKILLS
# Python TECHNICAL SKILLS
# HTML TECHNICAL SKILLS
# CSS TECHNICAL SKILLS
# Bootstrap TECHNICAL SKILLS
# MySQL TECHNICAL SKILLS
# IntelliJ IDEA TECHNICAL SKILLS
# Visual Studio TECHNICAL SKILLS
# GIT TECHNICAL SKILLS
# Bitbucket TECHNICAL SKILLS
# Windows TECHNICAL SKILLS
# Linux TECHNICAL SKILLS
# https://www.linkedin.com/in/ma
# leesha-thalagala/ LINKEDIN URL
# https://github.com/MaleeshaTha
# lagala96 GITHUB URL
# Software Engineering Intern at Information Systems Associates (Pvt)Ltd:
#  August 2019 – January 2020 EXPERIENCES
# Blogger at Medium: https://maleesha-16.medium.com/ OTHER EXPERIENCES
# Writer at LinkIT -Information Technology Society (INTECS) -
# Faculty of Information Technology OTHER EXPERIENCES
# Company coordinator – “FIT Future Careers 2020” OTHER EXPERIENCES
# Member of Junior western band and Senior brass band of Gothami
# Balika Vidyalaya. (2007-2011) OTHER EXPERIENCES
# Member of Swimming Club of Gothami Balika Vidyalaya. (2008-2009) OTHER EXPERIENCES
# Member of Buddhist Society and Art Society of Gothami Balika
# Vidyalaya. OTHER EXPERIENCES
# Spring boot TECHNICAL SKILLS
# Selenium TECHNICAL SKILLS
# Cucumber TECHNICAL SKILLS
# ANTLR TECHNICAL SKILLS
# Apache
# freemarker TECHNICAL SKILLS
# Google Colab TECHNICAL SKILLS
# Maven TECHNICAL SKILLS
# Gradle TECHNICAL SKILLS
# JIRA TECHNICAL SKILLS
# BDD TECHNICAL SKILLS
# Level-2 Software Project: Community Portal PROJECTS
# Level-1 Hardware Project: Attendance Information Display Board PROJECTS
# Interpersonal skills NON TECHNICAL SKILLS
# Quick Learner NON TECHNICAL SKILLS
# Communication NON TECHNICAL SKILLS
# Teamwork skills NON TECHNICAL SKILLS
# Leadership NON TECHNICAL SKILLS

# %%
def split_data(dataset_path, training_data_path, testing_data_path, train_ratio=0.8):
    # Create directories for train and test datasets if they don't exist
    training_data_path.mkdir(parents=True, exist_ok=True)
    testing_data_path.mkdir(parents=True, exist_ok=True)

    # Gather all .spacy files in dataset directory
    all_files = list(dataset_path.glob('*.spacy'))
    random.shuffle(all_files)  # Shuffle to randomize

    # Calculate split index
    split_idx = int(len(all_files) * train_ratio)

    # Split files into training and testing
    train_files = all_files[:split_idx]
    test_files = all_files[split_idx:]

    # Move files to respective directories
    for file in train_files:
        shutil.move(str(file), str(training_data_path / file.name))

    for file in test_files:
        shutil.move(str(file), str(testing_data_path / file.name))

    print(f"Training files: {len(train_files)} moved to {training_data_path}")
    print(f"Testing files: {len(test_files)} moved to {testing_data_path}")

split_data(Path(spacy_dataset_path),Path(training_data_path), Path(testing_data_path))
# Out:
# Training files: 424 moved to /content/drive/MyDrive/RashmikaFYP/training_data
# Testing files: 106 moved to /content/drive/MyDrive/RashmikaFYP/testing_data

# %%
# !python -m spacy debug data /content/drive/MyDrive/resume-shortlister/config/final_config.cfg
# Out:
# ============================ Data file validation ============================
# ✔ Pipeline can be initialized with data
# ✔ Corpus is loadable
#
# =============================== Training stats ===============================
# Language: en
# Training pipeline: tok2vec, ner
# 424 training docs
# 106 evaluation docs
# ✔ No overlap between training and evaluation data
# ⚠ Low number of examples to train a new pipeline (424)
#
# ============================== Vocab & Vectors ==============================
# ℹ 84314 total word(s) in the data (7689 unique)
# ℹ No word vectors present in the package
#
# ========================== Named Entity Recognition ==========================
# ℹ 11 label(s)
# 0 missing value(s) (tokens with '-' label)
# ✔ Good amount of examples for all labels
# ✔ Examples without occurrences available for all labels
# ✔ No entities consisting of or starting/ending with whitespace
# ✔ No entities crossing sentence boundaries
#
# ================================== Summary ==================================
# ✔ 7 checks passed
# ⚠ 1 warning

# %%
# !python -m spacy train /content/drive/MyDrive/resume-shortlister/config/final_config.cfg --output /content/drive/MyDrive/resume-shortlister/outputs/ --gpu-id 0
# Out:
# ℹ Saving to output directory:
# /content/drive/MyDrive/RashmikaFYP/outputs
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     54.30    0.00    0.00    0.00    0.00
#   0     100       2574.46   6951.02   19.39   34.08   13.55    0.19
#   0     200       3842.57   4774.85   35.73   46.06   29.19    0.36
#   0     300       4556.45   3249.31   82.28   86.03   78.85    0.82
#   0     400       3172.78   2567.83   85.44   87.03   83.92    0.85
#   1     500       1364.54   1437.53   88.96   92.73   85.48    0.89
#   1     600       1557.72   1376.10   87.08   86.82   87.34    0.87
#   1     700        785.37    834.03   89.61   90.32   88.91    0.90
#   1     800       8399.47   1303.93   89.46   90.11   88.83    0.89
#   2     900       1104.87    990.90   90.49   91.41   89.58    0.90
#   2    1000        743.08    628.56   87.95   87.88   88.01    0.88
#   2    1100       1182.35    822.65   90.73   90.76   90.69    0.91
#   2    1200       1614.36   1097.45   91.42   93.67   89.28    0.91
#   3    1300       1354.38    958.86   90.70   92.90   88.61    0.91
#   3    1400       2011.29    808.56   90.65   93.37   88.09    0.91
#   3    1500       4062.71    668.10   88.46   89.92   87.04    0.88
#   3    1600       2970.28   1073.24   89.83   95.47   84.81    0.90
#   4    1700       1634.14    862.03   87.37   83.65   91.44    0.87
# ✔ Saved pipeline to output directory
# /content/drive/MyDrive/RashmikaFYP/outputs/model-last

# %% [markdown]
# # Using the model

# %%
# !pip install spacy pdfplumber
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.4)
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.10/dist-packages (0.11.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: pdfminer.six==20231228 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (9.4.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (4.29.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (42.0.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)

# %%
import pdfplumber
import re
from datetime import datetime

# Path to your trained model
model_path = "/content/drive/MyDrive/resume-shortlister/outputs/model-best"  # or model-last
# Directory containing PDFs
pdf_directory = "/content/drive/MyDrive/resume-shortlister/resumes/"
nlp = spacy.load(model_path)  # Load your trained spaCy model

# %%
def extract_text_from_pdf(pdf_path):
    """Extract text from a PDF using pdfplumber."""
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            page_text = page.extract_text()
            if page_text:
                text += page_text
            # else:
                # print(f"No text found on one of the pages of {pdf_path}")
    return text

def extract_gpa(text):
    """Extract GPA using regex from provided text."""
    gpa_pattern = r"\b(?:GPA|CGPA)[:\s]*([\d\.]+)\b"
    match = re.search(gpa_pattern, text, re.IGNORECASE)
    if match:
        return float(match.group(1))
    return None

def score_skills(entity_text, skills_dict):
    """Calculate the score for given skills in a case-insensitive manner."""
    entity_text_lower = entity_text.lower()
    return sum(points for skill, points in skills_dict.items() if skill.lower() in entity_text_lower)

def calculate_experience_years(text):
    """Calculate total experience by finding all years mentioned in the text."""
    current_year = datetime.now().year
    years = re.findall(r'\b(20\d{2})\b', text)  # Match pattern like '2020'
    years = list(map(int, years))
    if not years:
        return 0
    years.sort()
    # Calculate experience as difference between the earliest and latest year mentioned plus one
    total_experience = max(years) - min(years) + 1
    return total_experience

# %%
pdf_paths = list(Path(pdf_directory).glob("*.pdf"))  # List all PDF files in the directory

if pdf_paths:  # Check if there's at least one PDF
    pdf_path = pdf_paths[23]  # Select the first PDF
    with pdfplumber.open(pdf_path) as pdf:
        text = extract_text_from_pdf(str(pdf_path))
        doc = nlp(text)
        # Print each detected entity and its label
        for ent in doc.ents:
            print(f"Label: {ent.label_} - Entity: {ent.text}")
else:
    print("No PDF files found in the directory.")
# Out:
# Label: CANDIDATE NAME - Entity: YASIRU WITHANAGE
# Label: DEGREE - Entity: B.SC (HONS.) IN INFORMATION TECHNOLOGY
# Label: DEGREE - Entity: B.Sc (Hons) Degree in Information Technology
# Label: GITHUB URL - Entity: https://github.com/withanageyasiru
# Label: NON TECHNICAL SKILLS - Entity: Leadership skill
# Label: NON TECHNICAL SKILLS - Entity: Quick learner
# Label: PROJECTS - Entity: SMART TRAINER - INTERN PROJECT
# DYNAMIC OBJECT-ORIENTED VIDEO AND
# PROGRAMMING PROGRAMMING GRAPHIC DESIGN In this project, data was taken by Multi Sensored Arduino T-shirt and passed to
# HOBBIES the server by using a connected mobile device
# Label: TECHNICAL SKILLS - Entity: Visual Studio
# Label: PROJECTS - Entity: AUGMENTED REALITY-BASED INDOOR NAVIGATION SYSTEM
# (cid:44)(cid:81)(cid:71)(cid:82)(cid:82)(cid:85)(cid:3)(cid:81)(cid:68)(cid:89)(cid:76)(cid:74)(cid:68)(cid:87)(cid:76)(cid:82)(cid:81)(cid:3)(cid:86)(cid:92)(cid:4235)(cid:72)(cid:80)(cid:3)(cid:90)(cid:75)(cid:76)(cid:70)(cid:75)(cid:3)(cid:68)(cid:79)(cid:79)(cid:82)(cid:90)(cid:86)(cid:3)(cid:87)(cid:82)(cid:3)(cid:3)(cid:86)(cid:72)(cid:79)(cid:72)(cid:70)(cid:87)(cid:3)(cid:68)(cid:3)(cid:71)(cid:72)(cid:4235)(cid:76)(cid:81)(cid:68)(cid:87)(cid:76)(cid:82)(cid:81)(cid:3)(cid:82)(cid:85)(cid:3)(cid:68)(cid:3)(cid:83)(cid:82)(cid:76)(cid:81)(cid:87)(cid:3)(cid:82)(cid:73)(cid:3)(cid:76)(cid:81)(cid:87)(cid:72)(cid:85)(cid:72)(cid:4235)(cid:15)(cid:3)(cid:68)(cid:81)(cid:71)(cid:3)(cid:68)(cid:73)(cid:87)(cid:72)(cid:85)(cid:3)(cid:87)(cid:75)(cid:68)(cid:87)(cid:3)(cid:68)(cid:3)(cid:85)(cid:82)(cid:88)(cid:87)(cid:72)(cid:3)(cid:87)(cid:82)(cid:3)
# (cid:87)(cid:75)(cid:72)(cid:3)(cid:86)(cid:72)(cid:79)(cid:72)(cid:70)(cid:87)(cid:72)(cid:71)(cid:3)(cid:71)(cid:72)(cid:4235)(cid:76)(cid:81)(cid:68)(cid:87)(cid:76)(cid:82)(cid:81)(cid:3)(cid:76)(cid:86)(cid:3)(cid:71)(cid:76)(cid:86)(cid:83)(cid:79)(cid:68)(cid:92)(cid:72)(cid:71)(cid:3)(cid:87)(cid:75)(cid:85)(cid:82)(cid:88)(cid:74)(cid:75)(cid:3)(cid:87)(cid:75)(cid:72)(cid:3)(cid:70)(cid:68)(cid:80)(cid:72)(cid:85)(cid:68)(cid:17)(cid:3)(cid:55)(cid:75)(cid:76)(cid:86)(cid:3)(cid:86)(cid:92)(cid:4235)(cid:72)(cid:80)(cid:3)(cid:76)(cid:86)(cid:3)(cid:80)(cid:68)(cid:76)(cid:81)(cid:79)(cid:92)(cid:3)(cid:73)(cid:82)(cid:70)(cid:88)(cid:86)(cid:72)(cid:71)(cid:3)(cid:82)(cid:81)(cid:3)(cid:70)(cid:88)(cid:4235)(cid:82)(cid:80)(cid:72)(cid:85)(cid:86)(cid:3)(cid:82)(cid:73)(cid:3)(cid:68)(cid:3)
# shopping complex
# Label: TECHNICAL SKILLS - Entity: Visual Studio
# Label: PROJECTS - Entity: LEVEL 2 SOFTWARE PROJECT :
# For SimCentric company’s asset tranfering among various job roles of the employees , using web
# (cid:68)(cid:83)(cid:79)(cid:76)(cid:70)(cid:68)(cid:87)(cid:76)(cid:82)(cid:81)(cid:3)(cid:90)(cid:75)(cid:76)(cid:70)(cid:75)(cid:3)(cid:73)(cid:68)(cid:70)(cid:76)(cid:79)(cid:76)(cid:87)(cid:68)(cid:87)(cid:72)(cid:86)(cid:3)(cid:87)(cid:75)(cid:72)(cid:3)(cid:68)(cid:88)(cid:87)(cid:82)(cid:80)(cid:68)(cid:87)(cid:72)(cid:71)(cid:3)(cid:80)(cid:68)(cid:81)(cid:68)(cid:74)(cid:72)(cid:80)(cid:72)(cid:81)(cid:87)(cid:3)(cid:82)(cid:73)(cid:3)(cid:68)(cid:86)(cid:86)(cid:72)(cid:87)(cid:3)(cid:87)(cid:85)(cid:68)(cid:81)(cid:86)(cid:73)(cid:72)(cid:85)(cid:76)(cid:81)(cid:74)(cid:3)(cid:68)(cid:81)(cid:71)(cid:3)(cid:71)(cid:76)(cid:4235)(cid:85)(cid:76)(cid:69)(cid:88)(cid:87)(cid:76)(cid:82)(cid:81)(cid:3)(cid:68)(cid:79)(cid:82)(cid:81)(cid:74)(cid:3)(cid:90)(cid:76)(cid:87)(cid:75)(cid:3)(cid:68)(cid:81)(cid:3)
# (cid:72)(cid:80)(cid:68)(cid:76)(cid:79)(cid:3)(cid:81)(cid:82)(cid:87)(cid:76)(cid:191)(cid:70)(cid:68)(cid:87)(cid:76)(cid:82)(cid:81)(cid:3)(cid:68)(cid:81)(cid:71)(cid:3)(cid:54)(cid:48)(cid:54)(cid:3)(cid:68)(cid:79)(cid:72)(cid:85)(cid:87)(cid:76)(cid:81)(cid:74)(cid:3)(cid:3)(cid:86)(cid:72)(cid:85)(cid:89)(cid:76)(cid:70)(cid:72)(cid:17)
# Used technologies - php laravel , MySql , Redis , Web Sockets , ReactJs ,MVC Architecture , node.js
# EXTRACURRICULAR ACTIVITIES
# Rotaract Club of University of Moratuwa
# Are You Ready - 2018 Career fair - photographer and company coordinator
# MoraMedics - 2018 - Photographer
# ESports - 2018 photographer
# FIT Moments Club
# (cid:3) (cid:50)(cid:4232)(cid:70)(cid:76)(cid:68)(cid:79)(cid:3)(cid:83)(cid:75)(cid:82)(cid:87)(cid:82)(cid:74)(cid:85)(cid:68)(cid:83)(cid:75)(cid:72)(cid:85)(cid:3)
# Label: PROJECTS - Entity: Isuru Sanjaya Wijayabandara
# Senior Software Engineer Associate Tech Lead
# SimCentric Technologies Pvt

# %%
def shortlist_pdfs(pdf_directory, nlp, gpa_range=(2.0, 4.0), tech_skills_points=None, non_tech_skills_points=None):
    if tech_skills_points is None:
        tech_skills_points = {"python": 2, "machine learning": 3, "java": 5, "sql": 2}
    if non_tech_skills_points is None:
        non_tech_skills_points = {"leadership": 1, "teamwork": 1}

    shortlisted_pdfs = []

    for pdf_path in Path(pdf_directory).glob("*.pdf"):
        text = extract_text_from_pdf(str(pdf_path))
        doc = nlp(text)
        score = 0

        # Extract GPA and calculate score
        gpa = extract_gpa(text)
        if gpa and gpa_range[0] <= gpa <= gpa_range[1]:
            score += 5

        # Calculate scores from skills
        for ent in doc.ents:
            if ent.label_ == "TECHNICAL SKILLS":
                score += score_skills(ent.text, tech_skills_points)
            elif ent.label_ == "NON TECHNICAL SKILLS":
                score += score_skills(ent.text, non_tech_skills_points)

        # Calculate experience years and add to score
        experience_years = calculate_experience_years(text)
        score += experience_years  # Add one point per year of experience

        shortlisted_pdfs.append((pdf_path.name, score))
        # print(f"Shortlisted: {pdf_path.name} with score: {score}")

    # Sort the list of shortlisted PDFs by score in descending order
    shortlisted_pdfs.sort(key=lambda x: x[1], reverse=True)
    return shortlisted_pdfs

# %%
shortlisted_pdfs = shortlist_pdfs(pdf_directory, nlp)

# Output the names of shortlisted PDFs in descending order of scores
print("Shortlisted PDFs in Descending Order of Scores:")
for pdf, score in shortlisted_pdfs[:20]:  # Limit to top 15
    print(f"{pdf}: {score}")
# Out:
# Shortlisted PDFs in Descending Order of Scores:
# Milinda_Senaka_SE - Milinda Nandasena.pdf: 43
# Janakee_Herath_SE - janakee herath.pdf: 40
# Gihan_Kadawathage.pdf: 39
# Chanduka_Samarasinghe.pdf: 39
# Sinthujan.P_SE - Sinthujan Sintha.pdf: 38
# lihini_jinanjalie QA - Lihini Jinanjalie.pdf: 37
# Manodya_Abeysinghe_SE - Manodya Abeysinghe.pdf: 36
# Udara_Wanasinghe_SE - W.A.U. WANASINGHE.pdf: 35
# Nawodani_Jayasooriya_SE - W.M.L.N.K. JAYASOORIYA.pdf: 35
# Sachith_Priyashantha_SE - R.S.S.S PRIYASHANTHA.pdf: 35
# Vidya_Wimalasooriya.pdf: 35
# Kelum_Sampath_SE - kelum sampath.pdf: 34
# vaishnavi_QA - V. VELLAIPANDIAN.pdf: 33
# Sanduni_Tharaka_SE - sanduni tharaka.pdf: 33
# vaishnavi_QA (2) - vaishnavi pandiyan.pdf: 33
# Nimesha_Herath_SE - H.M.N.D. HERATH.pdf: 31
# Mahesh_Sarathchandra_SE - mahesh sarathchandra.pdf: 31
# Sadheera_Mahanama_SE - S.S. MAHANAMA.pdf: 31
# Sanduni_Wickramathunga_SE - sanduni wickramathunga.pdf: 31
# Sanka_Dilshan_SE - sanka dilshan.pdf: 31
